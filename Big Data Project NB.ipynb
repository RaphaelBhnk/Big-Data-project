# %% [markdown]
# First we import all the librarys/models we need for this project

# %%
import mlflow
import mlflow.sklearn
import pandas as pd
import matplotlib.pyplot as plt

from numpy import savetxt

from sklearn.model_selection import train_test_split
from sklearn.datasets import load_diabetes

from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error

# %% [markdown]
# Then we import the data from de coinmarketcap API. We had to create an account there in order to get an API key. We used this key in order to obtain the 5000 last lines of data there are on the API. We couldn't load data in real time or more lines because we use a free account on Coinmarketcap.

# %%
#This example uses Python 2.7 and the python-request library.

from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'5000',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': 'f6dc697a-c189-4f67-bd7a-4b4768976d31',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)
# Out:
# {'status': {'timestamp': '2021-12-31T16:34:14.424Z', 'error_code': 0, 'error_message': None, 'elapsed': 469, 'credit_count': 25, 'notice': None, 'total_count': 8700}, 'data': [{'id': 1, 'name': 'Bitcoin', 'symbol': 'BTC', 'slug': 'bitcoin', 'num_market_pairs': 8922, 'date_added': '2013-04-28T00:00:00.000Z', 'tags': ['mineable', 'pow', 'sha-256', 'store-of-value', 'state-channel', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio', 'binance-labs-portfolio', 'blockchain-capital-portfolio', 'boostvc-portfolio', 'cms-holdings-portfolio', 'dcg-portfolio', 'dragonfly-capital-portfolio', 'electric-capital-portfolio', 'fabric-ventures-portfolio', 'framework-ventures-portfolio', 'galaxy-digital-portfolio', 'huobi-capital-portfolio', 'alameda-research-portfolio', 'a16z-portfolio', '1confirmation-portfolio', 'winklevoss-capital-portfolio', 'usv-portfolio', 'placeholder-ventures-portfolio', 'pantera-capital-portfolio', 'multicoin-capital-portfolio', 'paradigm-portfolio'], 'max_supply': 21000000, 'circulating_supply': 18915925, 'total_supply': 18915925, 'platform': None, 'cmc_rank': 1, 'last_updated': '2021-12-31T16:33:00.000Z', 'quote': {'USD': {'price': 48050.793124232, 'volume_24h': 32612533526.108036, 'volume_change_24h': 15.8324, 'percent_change_1h': 0.11496364, 'percent_change_24h': 1.6687892, 'percent_change_7d': -6.02435806, 'percent_change_30d': -18.18529221, 'percent_change_60d': -21.70909481, 'percent_change_90d': 0.38380333, 'market_cap': 908925198928.4882, 'market_cap_dominance': 40.3371, 'fully_diluted_market_cap': 1009066655608.87, 'last_updated': '2021-12-31T16:33:00.000Z'}}}, {'id': 1027, 'name': 'Ethereum', 'symbol': 'ETH', 'slug': 'ethereum', 'num_market_pairs': 5365, 'date_added': '2015-08-07T00:00:00.000Z', 'tags': ['mineable', 'pow', 'smart-contracts', 'ethereum-ecosystem', 'binance-smart-chain', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio', 'binance-labs-portfolio', 'blockchain-capital-portfolio', 'boostvc-portfolio', 'cms-holdings-portfolio', 'dcg-portfolio', 'dragonfly-capital-portfolio', 'electric-capital-portfolio', 'fabric-ventures-portfolio', 'framework-ventures-portfolio', 'hashkey-capital-portfolio', 'kenetic-capital-portfolio', 'huobi-capital-portfolio', 'alameda-research-portfolio', 'a16z-portfolio', '1confirmation-portfolio', 'winklevoss-capital-portfolio', 'usv-portfolio', 'placeholder-ventures-portfolio', 'pantera-capital-portfolio', 'multicoin-capital-portfolio', 'paradigm-portfolio'], 'max_supply': None, 'circulating_supply': 118968071.1865, 'total_supply': 118968071.1865, 'platform': None, 'cmc_rank': 2, 'last_updated': '2021-12-31T16:33:00.000Z', 'quote': {'USD': {'price': 3787.087165677843, 'volume_24h': 13048965407.021189, 'volume_change_24h': -12.2644, 'percent_change_1h': -0.18195831, 'percent_change_24h': 1.22949577, 'percent_change_7d': -7.57036094, 'percent_change_30d': -19.88953926, 'percent_change_60d': -12.73241711, 'percent_change_90d': 11.03350943, 'market_cap': 450542455515.84216, 'market_cap_dominance': 19.9946, 'fully_diluted_market_cap': 450542455515.84, 'last_updated': '2021-12-31T16:33:00.000Z'}}}, {'id': 1839, 'name': 'Binance Coin', 'symbol': 'BNB', 'slug': 'binance-coin', 'num_market_pairs': 601, 'date_added': '2017-07-25T00:00:00.000Z', 'tags': ['marketplace', 'centralized-exchange', 'payments', 'smart-contracts', 'binance-smart-chain', 'alameda-research-portfolio', 'multicoin-capital-portfolio'], 'max_supply': 166801148, 'circulating_supply': 166801148, 'total_supply': 166801148, 'platform': None, 'cmc_rank': 3, 'last_updated': '2021-12-31T16:33:00.000Z', 'quote': {'USD': {'price': 522.5580228219984, 'volume_24h': 1975031232.3554332, 'volume_change_24h': -4.5957, 'percent_change_1h': 0.02841676, 'percent_change_24h': 0.36680052, 'percent_change_7d': -4.81519677, 'percent_change_30d': -18.94347056, 'percent_change_60d': -2.94448157, 'percent_change_90d': 20.64403376, 'market_cap': 87163 ...
#
# *** WARNING: max output size exceeded, skipping output. ***
#
# 0.24985211, 'percent_change_30d': -48.06825988, 'percent_change_60d': -55.77508687, 'percent_change_90d': -55.77508687, 'market_cap': 0, 'market_cap_dominance': 0, 'fully_diluted_market_cap': 386022.96, 'last_updated': '2021-12-31T16:33:00.000Z'}}}, {'id': 14339, 'name': 'Cypherium', 'symbol': 'CPH', 'slug': 'cypherium', 'num_market_pairs': 3, 'date_added': '2021-11-11T08:57:37.000Z', 'tags': [], 'max_supply': 8428000000, 'circulating_supply': 0, 'total_supply': 6828000000, 'platform': None, 'cmc_rank': 4973, 'last_updated': '2021-12-31T16:27:00.000Z', 'quote': {'USD': {'price': 0.04024970644918541, 'volume_24h': 42132.41094737, 'volume_change_24h': 13.4488, 'percent_change_1h': 1.02256537, 'percent_change_24h': -2.22622518, 'percent_change_7d': -5.67735598, 'percent_change_30d': -58.75969367, 'percent_change_60d': -17.07542857, 'percent_change_90d': -17.07542857, 'market_cap': 0, 'market_cap_dominance': 0, 'fully_diluted_market_cap': 339224525.95, 'last_updated': '2021-12-31T16:27:00.000Z'}}}, {'id': 15239, 'name': 'Lord Arena', 'symbol': 'LORDA', 'slug': 'lord-arena', 'num_market_pairs': 2, 'date_added': '2021-12-01T10:07:50.000Z', 'tags': [], 'max_supply': 1000000000, 'circulating_supply': 0, 'total_supply': 0, 'platform': {'id': 1839, 'name': 'Binance Smart Chain (BEP20)', 'symbol': 'BNB', 'slug': 'binance-coin', 'token_address': '0xc326622fca914ca15fd44dd070232ce3cd358dde'}, 'cmc_rank': 4974, 'last_updated': '2021-12-31T16:33:00.000Z', 'quote': {'USD': {'price': 0.010602343738938954, 'volume_24h': 42109.91867421, 'volume_change_24h': 121.8393, 'percent_change_1h': -0.2271906, 'percent_change_24h': -5.20061037, 'percent_change_7d': -24.71190761, 'percent_change_30d': -79.72194626, 'percent_change_60d': -74.71266275, 'percent_change_90d': -74.71266275, 'market_cap': 0, 'market_cap_dominance': 0, 'fully_diluted_market_cap': 10602343.74, 'last_updated': '2021-12-31T16:33:00.000Z'}}}, {'id': 15372, 'name': 'Farm Planet', 'symbol': 'FPL', 'slug': 'farm-planet', 'num_market_pairs': 2, 'date_added': '2021-11-30T07:01:02.000Z', 'tags': [], 'max_supply': 10000000000, 'circulating_supply': 0, 'total_supply': 10000000000, 'platform': {'id': 1839, 'name': 'Binance Smart Chain (BEP20)', 'symbol': 'BNB', 'slug': 'binance-coin', 'token_address': '0xe5e29fc606a3002dec5663568bd6739ac0a6d41c'}, 'cmc_rank': 4975, 'last_updated': '2021-12-31T16:34:00.000Z', 'quote': {'USD': {'price': 0.00021519630256709837, 'volume_24h': 42029.05560238, 'volume_change_24h': -20.205, 'percent_change_1h': -0.06684264, 'percent_change_24h': -8.52240836, 'percent_change_7d': 2.51971984, 'percent_change_30d': -65.36079671, 'percent_change_60d': -79.09953, 'percent_change_90d': -79.09953, 'market_cap': 0, 'market_cap_dominance': 0, 'fully_diluted_market_cap': 2151963.03, 'last_updated': '2021-12-31T16:34:00.000Z'}}}, {'id': 6062, 'name': 'HUPAYX', 'symbol': 'HPX', 'slug': 'hupayx', 'num_market_pairs': 1, 'date_added': '2020-08-03T00:00:00.000Z', 'tags': [], 'max_supply': 10000000000, 'circulating_supply': 0, 'total_supply': 0, 'platform': None, 'cmc_rank': 4976, 'last_updated': '2021-12-31T16:34:00.000Z', 'quote': {'USD': {'price': 0.14760619892465937, 'volume_24h': 41888.81194579, 'volume_change_24h': -57.0859, 'percent_change_1h': -0.01199416, 'percent_change_24h': 2.49319119, 'percent_change_7d': -11.56324066, 'percent_change_30d': -35.73814799, 'percent_change_60d': -44.53946569, 'percent_change_90d': -26.20880136, 'market_cap': 0, 'market_cap_dominance': 0, 'fully_diluted_market_cap': 1476061989.25, 'last_updated': '2021-12-31T16:34:00.000Z'}}}, {'id': 5270, 'name': 'Freecash', 'symbol': 'FCH', 'slug': 'freecash', 'num_market_pairs': 3, 'date_added': '2020-03-09T00:00:00.000Z', 'tags': [], 'max_supply': None, 'circulating_supply': 0, 'total_supply': 4979700, 'platform': None, 'cmc_rank': 4977, 'last_updated': '2021-12-31T16:33:00.000Z', 'quote': {'USD': {'price': 0.01899649581374443, 'volume_24h': 41783.16152601, 'volume_change_24h': -73.9367, 'percent_change_ ...

# %% [markdown]
# So now we have a lot of data on the biggest 50 cryptocurrencies. We have now to clean and preprocess the data in order to use a model.

# %% [markdown]
# First, we decided to use an other format for our data. Indeed, we have a JSON file but it's better to maniuplate a dataframe in order to clean the dataset. Then we display the data:

# %%
df = pd.DataFrame(data["data"])
df.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>name</th>
#       <th>symbol</th>
#       <th>slug</th>
#       <th>num_market_pairs</th>
#       <th>date_added</th>
#       <th>tags</th>
#       <th>max_supply</th>
#       <th>circulating_supply</th>
#       <th>total_supply</th>
#       <th>platform</th>
#       <th>cmc_rank</th>
#       <th>last_updated</th>
#       <th>quote</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>Bitcoin</td>
#       <td>BTC</td>
#       <td>bitcoin</td>
#       <td>8922</td>
#       <td>2013-04-28T00:00:00.000Z</td>
#       <td>[mineable, pow, sha-256, store-of-value, state...</td>
#       <td>21000000.0</td>
#       <td>1.891592e+07</td>
#       <td>1.891592e+07</td>
#       <td>None</td>
#       <td>1</td>
#       <td>2021-12-31T16:33:00.000Z</td>
#       <td>{'USD': {'price': 48050.793124232, 'volume_24h...</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1027</td>
#       <td>Ethereum</td>
#       <td>ETH</td>
#       <td>ethereum</td>
#       <td>5365</td>
#       <td>2015-08-07T00:00:00.000Z</td>
#       <td>[mineable, pow, smart-contracts, ethereum-ecos...</td>
#       <td>NaN</td>
#       <td>1.189681e+08</td>
#       <td>1.189681e+08</td>
#       <td>None</td>
#       <td>2</td>
#       <td>2021-12-31T16:33:00.000Z</td>
#       <td>{'USD': {'price': 3787.087165677843, 'volume_2...</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>1839</td>
#       <td>Binance Coin</td>
#       <td>BNB</td>
#       <td>binance-coin</td>
#       <td>601</td>
#       <td>2017-07-25T00:00:00.000Z</td>
#       <td>[marketplace, centralized-exchange, payments, ...</td>
#       <td>166801148.0</td>
#       <td>1.668011e+08</td>
#       <td>1.668011e+08</td>
#       <td>None</td>
#       <td>3</td>
#       <td>2021-12-31T16:33:00.000Z</td>
#       <td>{'USD': {'price': 522.5580228219984, 'volume_2...</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>825</td>
#       <td>Tether</td>
#       <td>USDT</td>
#       <td>tether</td>
#       <td>25057</td>
#       <td>2015-02-25T00:00:00.000Z</td>
#       <td>[payments, stablecoin, asset-backed-stablecoin...</td>
#       <td>NaN</td>
#       <td>7.833688e+10</td>
#       <td>8.175899e+10</td>
#       <td>{'id': 1027, 'name': 'Ethereum', 'symbol': 'ET...</td>
#       <td>4</td>
#       <td>2021-12-31T16:34:00.000Z</td>
#       <td>{'USD': {'price': 1.0000419981345485, 'volume_...</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>5426</td>
#       <td>Solana</td>
#       <td>SOL</td>
#       <td>solana</td>
#       <td>215</td>
#       <td>2020-04-10T00:00:00.000Z</td>
#       <td>[pos, platform, solana-ecosystem, cms-holdings...</td>
#       <td>NaN</td>
#       <td>3.094838e+08</td>
#       <td>5.116169e+08</td>
#       <td>None</td>
#       <td>5</td>
#       <td>2021-12-31T16:34:00.000Z</td>
#       <td>{'USD': {'price': 175.92551007747838, 'volume_...</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df.shape
# Out:
# Out[54]: (5000, 14)

# %% [markdown]
# We choose to delete some columns that werent useful for the training of our model

# %%
df = df.drop(['slug', 'date_added','platform','cmc_rank'], axis=1)

# %% [markdown]
# We modified the quote column which was composed of JSON data.

# %%
print(type(df['quote'][0]))
df['quote'] = df['quote'].apply(lambda x: x['USD'])
# Out:
# <class 'dict'>

# %%
df.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>name</th>
#       <th>symbol</th>
#       <th>num_market_pairs</th>
#       <th>tags</th>
#       <th>max_supply</th>
#       <th>circulating_supply</th>
#       <th>total_supply</th>
#       <th>last_updated</th>
#       <th>quote</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>Bitcoin</td>
#       <td>BTC</td>
#       <td>8922</td>
#       <td>[mineable, pow, sha-256, store-of-value, state...</td>
#       <td>21000000.0</td>
#       <td>1.891592e+07</td>
#       <td>1.891592e+07</td>
#       <td>2021-12-31T16:33:00.000Z</td>
#       <td>{'price': 48050.793124232, 'volume_24h': 32612...</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1027</td>
#       <td>Ethereum</td>
#       <td>ETH</td>
#       <td>5365</td>
#       <td>[mineable, pow, smart-contracts, ethereum-ecos...</td>
#       <td>NaN</td>
#       <td>1.189681e+08</td>
#       <td>1.189681e+08</td>
#       <td>2021-12-31T16:33:00.000Z</td>
#       <td>{'price': 3787.087165677843, 'volume_24h': 130...</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>1839</td>
#       <td>Binance Coin</td>
#       <td>BNB</td>
#       <td>601</td>
#       <td>[marketplace, centralized-exchange, payments, ...</td>
#       <td>166801148.0</td>
#       <td>1.668011e+08</td>
#       <td>1.668011e+08</td>
#       <td>2021-12-31T16:33:00.000Z</td>
#       <td>{'price': 522.5580228219984, 'volume_24h': 197...</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>825</td>
#       <td>Tether</td>
#       <td>USDT</td>
#       <td>25057</td>
#       <td>[payments, stablecoin, asset-backed-stablecoin...</td>
#       <td>NaN</td>
#       <td>7.833688e+10</td>
#       <td>8.175899e+10</td>
#       <td>2021-12-31T16:34:00.000Z</td>
#       <td>{'price': 1.0000419981345485, 'volume_24h': 52...</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>5426</td>
#       <td>Solana</td>
#       <td>SOL</td>
#       <td>215</td>
#       <td>[pos, platform, solana-ecosystem, cms-holdings...</td>
#       <td>NaN</td>
#       <td>3.094838e+08</td>
#       <td>5.116169e+08</td>
#       <td>2021-12-31T16:34:00.000Z</td>
#       <td>{'price': 175.92551007747838, 'volume_24h': 13...</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df['quote'][0]
# Out:
# Out[58]: {'price': 48050.793124232,
#  'volume_24h': 32612533526.108036,
#  'volume_change_24h': 15.8324,
#  'percent_change_1h': 0.11496364,
#  'percent_change_24h': 1.6687892,
#  'percent_change_7d': -6.02435806,
#  'percent_change_30d': -18.18529221,
#  'percent_change_60d': -21.70909481,
#  'percent_change_90d': 0.38380333,
#  'market_cap': 908925198928.4882,
#  'market_cap_dominance': 40.3371,
#  'fully_diluted_market_cap': 1009066655608.87,
#  'last_updated': '2021-12-31T16:33:00.000Z'}

# %% [markdown]
# We create to columns(volume_change_24h and percent_change_7d).
# The fist one is the datat we will predict.
# The second one will help us to train the model.

# %%
df['volume_change_24h'] = df['quote'].apply(lambda x: x['volume_change_24h'])

# %%
df['percent_change_7d'] = df['quote'].apply(lambda x: x['percent_change_7d'])

# %%
df['max_supply'].value_counts()
df = df.drop(['max_supply'], axis=1)

# %% [markdown]
# Now we have the updated dataset

# %%
df.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>name</th>
#       <th>symbol</th>
#       <th>num_market_pairs</th>
#       <th>tags</th>
#       <th>circulating_supply</th>
#       <th>total_supply</th>
#       <th>last_updated</th>
#       <th>quote</th>
#       <th>volume_change_24h</th>
#       <th>percent_change_7d</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>Bitcoin</td>
#       <td>BTC</td>
#       <td>8922</td>
#       <td>[mineable, pow, sha-256, store-of-value, state...</td>
#       <td>1.891592e+07</td>
#       <td>1.891592e+07</td>
#       <td>2021-12-31T16:33:00.000Z</td>
#       <td>{'price': 48050.793124232, 'volume_24h': 32612...</td>
#       <td>15.8324</td>
#       <td>-6.024358</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1027</td>
#       <td>Ethereum</td>
#       <td>ETH</td>
#       <td>5365</td>
#       <td>[mineable, pow, smart-contracts, ethereum-ecos...</td>
#       <td>1.189681e+08</td>
#       <td>1.189681e+08</td>
#       <td>2021-12-31T16:33:00.000Z</td>
#       <td>{'price': 3787.087165677843, 'volume_24h': 130...</td>
#       <td>-12.2644</td>
#       <td>-7.570361</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>1839</td>
#       <td>Binance Coin</td>
#       <td>BNB</td>
#       <td>601</td>
#       <td>[marketplace, centralized-exchange, payments, ...</td>
#       <td>1.668011e+08</td>
#       <td>1.668011e+08</td>
#       <td>2021-12-31T16:33:00.000Z</td>
#       <td>{'price': 522.5580228219984, 'volume_24h': 197...</td>
#       <td>-4.5957</td>
#       <td>-4.815197</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>825</td>
#       <td>Tether</td>
#       <td>USDT</td>
#       <td>25057</td>
#       <td>[payments, stablecoin, asset-backed-stablecoin...</td>
#       <td>7.833688e+10</td>
#       <td>8.175899e+10</td>
#       <td>2021-12-31T16:34:00.000Z</td>
#       <td>{'price': 1.0000419981345485, 'volume_24h': 52...</td>
#       <td>-9.7481</td>
#       <td>-0.025268</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>5426</td>
#       <td>Solana</td>
#       <td>SOL</td>
#       <td>215</td>
#       <td>[pos, platform, solana-ecosystem, cms-holdings...</td>
#       <td>3.094838e+08</td>
#       <td>5.116169e+08</td>
#       <td>2021-12-31T16:34:00.000Z</td>
#       <td>{'price': 175.92551007747838, 'volume_24h': 13...</td>
#       <td>-28.2281</td>
#       <td>-10.545477</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# Then, we use Mlflow in order to get historical results of our model and save our predictions:

# %%
X = df.drop(['id','name','symbol','tags','last_updated','quote','percent_change_7d'], axis=1)
y = df['percent_change_7d']
X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
# Enable autolog()
# mlflow.sklearn.autolog() requires mlflow 1.11.0 or above.
mlflow.sklearn.autolog()
 
# With autolog() enabled, all model parameters, a model score, and the fitted model are automatically logged.  
with mlflow.start_run():
  
  # Set the model parameters. 
  n_estimators = 100
  max_depth = 5
  max_features = 3
  
  # Create and train model.
  rf = RandomForestRegressor(n_estimators = n_estimators, max_depth = max_depth, max_features = max_features)
  rf.fit(X_train, y_train)
  
  # Use the model to make predictions on the test dataset.
  predictions = rf.predict(X_test)
# Out:
# 2021/12/31 16:34:17 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/databricks/python/lib/python3.8/site-packages/mlflow/models/signature.py:129: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
